# %%
"""
Created on:1/27/2020
@author:Marvin Senjaliya
"""
"""
problem statement:
Inventory Management Program
Desc -> Extend the above program to Create InventoryManager to manage the Inventory. The Inventory Manager will use InventoryFactory to create Inventory Object from JSON. The InventoryManager will call each Inventory Object in its list to calculate the Inventory Price and then call the Inventory Object to return the JSON String. The main program will be with InventoryManager
I/P -> read in JSON File
Logic -> Get JSON Object in Java or NSDictionary in iOS. Create Inventory Object from JSON. Calculate the value for every Inventory. 
O/P -> Create the JSON from Inventory Object and output the JSON String.
"""

# %%
import json

class InventoryFactory:
    
    def __init__(self):
        self.data = dict(rice=[],pulses=[],wheat=[])
        
    def additem(self,item_type,name,weight,price):
        self.data[item_type].append({'name':name,'weight':weight,'price':price})
        
    def totalprice(self,item,sub_item,total_price):
        self.data[item][sub_item]['total_price']=total_price
        
    def total_inventory(self):
        self.json_string = json.dumps(self.data)
        return self.json_string
    
class InventoryManager:
    
    def __init__(self):
        self.inventory_obj=InventoryFactory()
        
    def addStock(self): 
        
        
        for index in range(int(input("please,Enter the number of item you want to add in rice:"))):
            name=input("name:")
            weight=input("weight:")
            price=input("price:")
            self.inventory_obj.additem('rice',name,weight,price) 
            
            
        for index in range(int(input("please,Enter the number of item you want to add in pulse:"))):
            name=input("name:")
            weight=input("weight:")
            price=input("price:")
            self.inventory_obj.additem('pulses',name,weight,price)
            
        
        for index in range(int(input("please,Enter the number of item you want to add in wheat:"))):
            name=input("name:")
            weight=input("weight:")
            price=input("price:")
            self.inventory_obj.additem('wheat',name,weight,price)
            
    def calculatevalue(self):
        
        stock=json.loads(self.inventory_obj.total_inventory())
        for item in stock:
            for sub_item in range(0,len(stock[item])):
                total_price=stock[item][sub_item]['weight']*stock[item][sub_item]['price']
                self.inventory_obj.totalprice(item,sub_item,total_price)
            return self.inventory_obj.total_inventory()
                
            
if __name__='__main__':
    print("inventory management program")
    manager=inv
        
            
        
            

    def add_item(self,item,num,kg):
        self.python_data=json.loads(self.json_string)
        if num==1:
            print(self.python_data['rice'])
            self.item_value=kg*self.python_data['rice'][0]['price']
            print("your Bill is:",self.item_value)
        if num==2:
            print(self.python_data['pulses'])
            self.item_value=kg*self.python_data['pulses'][0]['price']
            print("your Bill is:",self.item_value)
        if num==3:
            print(self.python_data['wheat'])
            self.item_value=kg*self.python_data['wheat'][0]['price']
            print("your Bill is:",self.item_value)
    def Inventory_manager(self):
        print("Total_inventory_value:")
        self.total_rice_value=self.data['rice'][0]['price']*self.data['rice'][0]['weight']
        print("total_rice_value:",self.total_rice_value)
        self.total_pulses_value=self.data['pulses'][0]['price']*self.data['rice'][0]['weight']
        print("total_pulses_value:",self.total_pulses_value)
        self.total_wheat_value=self.data['wheat'][0]['price']*self.data['wheat'][0]['weight']
        print("total_wheat_value:",self.total_wheat_value)
        if num==1:
            self.data['rice'][0]['weight']=self.data['rice'][0]['weight']+kg
            print("current_total_rice",self.data['rice'][0]['weight'])
            
        if num==2:
            self.data['pulses'][0]['weight']=self.data['pulses'][0]['weight']+kg
            print("current_total_pulses",self.data['pulses'][0]['weight'])
        
        if num==3:
            self.data['wheat'][0]['weight']=self.data['wheat'][0]['weight']+kg
            print("current_total_wheat",self.data['wheat'][0]['weight'])
        
    

if __name__=='__main__':
    
    data={'rice':[{'name': 'basmati', 'weight':100, 'price': 100}],
             'pulses':[{'name':'grain','weight':100,'price':200}],
             'wheat':[{'name':'peach','weight':100,'price':300}]}
    item=Item(data)
    item.Inventory_manager()
    #num=int(input("Enter your choice:\n1:for rice\n2:for pulse\n3:for wheat"))
    #kg=int(input("Enter how many kg you want??"))
    num=int(input("Enter your choice which item you want to add:\n1:for rice\n2:for pulse\n3:for wheat"))
    kg=int(input("Enter how many kg you want to add:"))
    #item.get_val(num,kg)
    item.Inventory_manager()
# Out:
# Total_inventory_value:
# total_rice_value: 10000
# total_pulses_value: 20000
# total_wheat_value: 30000
# current_total_wheat 110
# Enter your choice which item you want to add:
# 1:for rice
# 2:for pulse
# 3:for wheat3
# Enter how many kg you want to add:10
# Total_inventory_value:
# total_rice_value: 10000
# total_pulses_value: 20000
# total_wheat_value: 33000
# current_total_wheat 120
